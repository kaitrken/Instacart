# %% [markdown]
# ### Contents
#
# Import data
#
# Merge df_prods with df_ords_prods
#
# Export data

# %% [markdown]
# ### Import data

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# import dataframe
path = r'/Users/kaitlinkendrick/Documents/Data Analysis/Instacart Basket Analysis'

# %%
df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# import prods.csv
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col=False)

# %%
# Check output
df_ords_prods.shape
# Out:
# (32434489, 13)

# %% [markdown]
# ### Merge df_prods with df_ords_prods

# %%
# merge df_prods w/ df_ords_prods
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_ords_prods.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    order_day_of_week  order_hour_of_day  days_since_previous_order  \
# 0                  2                  8                        NaN
# 1                  2                  8                        NaN
# 2                  2                  8                        NaN
# 3                  2                  8                        NaN
# 4                  2                  8                        NaN
#
#    t/f_days_since_previous_order  product_id  add_to_cart_order  reordered  \
# 0                          False         196                  1          0
# ...

# %% [markdown]
# use product_id as the merge code

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_ords_prods.shape
# Out:
# (32434489, 13)

# %%
# check merge before overwriting
pd.merge(df_prods, df_ords_prods, on = ['product_id'])
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 32404854         49692       49688      Fresh Foaming Cleanser        73
# 32404855         49692       49688      Fresh Foaming Cleanser        73
# 32404856         49692       49688      Fresh Foaming Cleanser        73
# 32404857         49692       49688      Fresh Foaming Cleanser        73
# 32404858         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  \
# ...

# %%
# merge df's
df_ords_prods_merge = df_prods.merge(df_ords_prods, on = 'product_id')

# %%
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  user_id  \
# 0             19     5.8          1987          1987   3139998      138
# 1             19     5.8          1989          1989   1977647      138
# 2             19     5.8         11433         11433    389851      709
# 3             19     5.8         12198         12198    652770      764
# 4             19     5.8         12200         12200   1813452      764
#
#    order_number  order_day_of_week  order_hour_of_day  \
# 0            28                  6                 11
# ...

# %%
# check merge flag
df_ords_prods_merge['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 18)

# %% [markdown]
# ### Export data

# %%
# export merged df in pickles
df_ords_prods_merge.to_pickle(os.path.join (path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
